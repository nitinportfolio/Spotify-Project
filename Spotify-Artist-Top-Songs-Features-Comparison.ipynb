# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

tokens_path = "D:\Various-APITokens-Details\spotify.txt"
access_token = open(tokens_path,"r").read().split()
client_id = access_token[2]
client_secret = access_token[-1]

# %%
auth_manager = SpotifyClientCredentials(client_id= client_id, client_secret=client_secret)

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_name = "Metallica"#"Arijit Singh"#'Black Sabbath'#"ozzy osbourne"

# %% [markdown]
# # Searching Artist

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=20)

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#   'followers': {'href': None, 'total': 26542349},
#   'genres': ['hard rock',
#    'metal',
#    'old school thrash',
#    'rock',
#    'thrash metal'],
#   'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#   'id': '2ye2Wgw4gimLv2eAKyk1NB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb69ca98dd3083f1082d740e44',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517469ca98dd3083f1082d740e44',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17869ca98dd3083f1082d740e44',
#     'width': 160}],
#   'name': 'Metallica',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2k6JE1LV7mSOavtrZ5m5qR'},
#   'followers': {'href': None, 'total': 1038},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/2k6JE1LV7mSOavtrZ5m5qR',
#   'id': '2k6JE1LV7mSOavtrZ5m5qR',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e0d2015304738c7bc08c5203',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e0d2015304738c7bc08c5203',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e0d2015304738c7bc08c5203',
#     'width': 64}],
#   'name': 'SaD - Symphony and Metallica',
#   'popularity': 10,
#   'type': 'artist',
#   'uri': 'spotify:artist:2k6JE1LV7mSOavtrZ5m5qR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Cb4VdtakIlAvklqegssGB'},
#   'followers': {'href': None, 'total': 12582},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7Cb4VdtakIlAvklqegssGB',
#   'id': '7Cb4VdtakIlAvklqegssGB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730baa189d8d5e6ca03a5adfed',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020baa189d8d5e6ca03a5adfed',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510baa189d8d5e6ca03a5adfed',
#     'width': 64}],
#   'name': 'Spartan Metallican Visionary',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:7Cb4VdtakIlAvklqegssGB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/47wBd6p1vSdIrgXxdc1Cde'},
#   'followers': {'href': None, 'total': 22},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/47wBd6p1vSdIrgXxdc1Cde',
#   'id': '47wBd6p1vSdIrgXxdc1Cde',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737ebaa72eca7e4cb70f4902ec',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027ebaa72eca7e4cb70f4902ec',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517ebaa72eca7e4cb70f4902ec',
#     'width': 64}],
#   'name': 'MetallicaMan',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:47wBd6p1vSdIrgXxdc1Cde'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7I2EiRxYEZigLPzgu43HWq'},
#   'followers': {'href': None, 'total': 240},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7I2EiRxYEZigLPzgu43HWq',
#   'id': '7I2EiRxYEZigLPzgu43HWq',
#   'images': [],
#   'name': 'Metallica: Burton',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:7I2EiRxYEZigLPzgu43HWq'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ouOJPakXli9ePEiCAHNqw'},
#   'followers': {'href': None, 'total': 59},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/2ouOJPakXli9ePEiCAHNqw',
#   'id': '2ouOJPakXli9ePEiCAHNqw',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb7a55ce88753288d435995791',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051747a55ce88753288d435995791',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1787a55ce88753288d435995791',
#     'width': 160}],
#   'name': 'Metallicash',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:2ouOJPakXli9ePEiCAHNqw'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4JMcZrg7tSw80yrzGl3JkB'},
#   'followers': {'href': None, 'total': 7},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/4JMcZrg7tSw80yrzGl3JkB',
#   'id': '4JMcZrg7tSw80yrzGl3JkB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c99087ef7466bbcc14f041a2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c99087ef7466bbcc14f041a2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c99087ef7466bbcc14f041a2',
#     'width': 64}],
#   'name': 'Metallica - Piano Covers',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:4JMcZrg7tSw80yrzGl3JkB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/55golvVPPZZAYSTDXt6Yfv'},
#   'followers': {'href': None, 'total': 88},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/55golvVPPZZAYSTDXt6Yfv',
#   'id': '55golvVPPZZAYSTDXt6Yfv',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ede2b9bbbc922f879d036747',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ede2b9bbbc922f879d036747',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ede2b9bbbc922f879d036747',
#     'width': 64}],
#   'name': 'SaD - European Metallica Tribute',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:55golvVPPZZAYSTDXt6Yfv'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7xXiZGPcqDEijirJubILoZ'},
#   'followers': {'href': None, 'total': 409},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7xXiZGPcqDEijirJubILoZ',
#   'id': '7xXiZGPcqDEijirJubILoZ',
#   'images': [],
#   'name': 'Made famous by Metallica',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:7xXiZGPcqDEijirJubILoZ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/61OPB1XJSYA5JoAvWZUQ4Z'},
#   'followers': {'href': None, 'total': 825},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/61OPB1XJSYA5JoAvWZUQ4Z',
#   'id': '61OPB1XJSYA5JoAvWZUQ4Z',
#   'images': [],
#   'name': 'Metallica Tribute Band',
#   'popularity': 3,
#   'type': 'artist',
#   'uri': 'spotify:artist:61OPB1XJSYA5JoAvWZUQ4Z'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#  'followers': {'href': None, 'total': 26542349},
#  'genres': ['hard rock', 'metal', 'old school thrash', 'rock', 'thrash metal'],
#  'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#  'id': '2ye2Wgw4gimLv2eAKyk1NB',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb69ca98dd3083f1082d740e44',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517469ca98dd3083f1082d740e44',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17869ca98dd3083f1082d740e44',
#    'width': 160}],
#  'name': 'Metallica',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:2ye2Wgw4gimLv2eAKyk1NB

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:20]:
    print('track    : ' + track['name'])
    print('track id : ' + track['id'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Enter Sandman (Remastered)
# track id : 3VqHuw0wFlIHcIPWkhIbdQ
# audio    : https://p.scdn.co/mp3-preview/333dcef73eb5aa95a58ff521fa63d14861dfe2f5?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b2731f9edf15e43f4c2f4938b869
#
# track    : Nothing Else Matters (Remastered)
# track id : 2CtemffYhT0DJWcT1XW047
# audio    : https://p.scdn.co/mp3-preview/830f0b836bc20723462da06d1ff779f7b9499a7e?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b2731f9edf15e43f4c2f4938b869
#
# track    : Master of Puppets (Remastered)
# track id : 54bm2e3tk8cliUz3VSdCPZ
# audio    : https://p.scdn.co/mp3-preview/0fdb849c9a1fa299ac76146ea3337c5c19820c07?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b273cad4832cb7b5844343278daa
#
# track    : For Whom The Bell Tolls (Remastered)
# track id : 51YZAJhOwIC5Gg3jMbAmhZ
# audio    : https://p.scdn.co/mp3-preview/e8650ac29782721b2b42943fa8ca3b49f77e0365?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b273533fd0b248052d04e6b732c0
#
# track    : One (Remastered)
# track id : 0LAcM6I7ijW4VVW0aytl1t
# audio    : https://p.scdn.co/mp3-preview/6e6f8324c485631dcfe1d23c664c1057428dcc6a?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b273be54746b374358970b5e617a
#
# track    : The Unforgiven (Remastered)
# track id : 7lwvxYumAEo10lzAplRGXM
# audio    : https://p.scdn.co/mp3-preview/8d88612fd8ab8f5176a2c6de3919fa449c981cde?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b2731f9edf15e43f4c2f4938b869
#
# track    : Whiskey In The Jar
# track id : 3ZpWy5rBZv2aLQAldnmTsP
# audio    : https://p.scdn.co/mp3-preview/a51c87c9b21c9e995d0b9d924d566570dc6d97a1?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b2737e1f85f69323acac962516c4
#
# track    : Sad But True (Remastered)
# track id : 5UaDi8KzCGJqFfVAOBfXhi
# audio    : https://p.scdn.co/mp3-preview/b524a437eaa3b3798fe2e651cfda5de7d4443f88?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b2731f9edf15e43f4c2f4938b869
#
# track    : Fuel
# track id : 1tTPC0hsnXq1IGpvWY54JC
# audio    : https://p.scdn.co/mp3-preview/d74f3ed17b0ade500e951522ddcefd20a632846c?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b273a49eff6d64cafc2551553380
#
# track    : Fade To Black (Remastered)
# track id : 0dqGfCMAGyDgpUAgLNOjWd
# audio    : https://p.scdn.co/mp3-preview/8f6f499c2a82f84a967fc14b9c1f60344b85b2ff?cid=45376cf3a63c421ba5e13941db6a213b
# cover art: https://i.scdn.co/image/ab67616d0000b273533fd0b248052d04e6b732c0

# %%
type(results)
# Out:
# dict

# %%
len(results["tracks"])
# Out:
# 10

# %%
results["tracks"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#     'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#     'id': '2ye2Wgw4gimLv2eAKyk1NB',
#     'name': 'Metallica',
#     'type': 'artist',
#     'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/55fq75UfkYbGMq4CncCtOH'},
#   'href': 'https://api.spotify.com/v1/albums/55fq75UfkYbGMq4CncCtOH',
#   'id': '55fq75UfkYbGMq4CncCtOH',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731f9edf15e43f4c2f4938b869',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021f9edf15e43f4c2f4938b869',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511f9edf15e43f4c2f4938b869',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Metallica (Remastered)',
#   'release_date': '1991-08-12',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:55fq75UfkYbGMq4CncCtOH'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#    'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#    'id': '2ye2Wgw4gimLv2eAKyk1NB',
#    'name': 'Metallica',
#    'type': 'artist',
#    'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'}],
#  'disc_number': 1,
#  'duration_ms': 331560,
#  'explicit': False,
#  'external_ids': {'isrc': 'QMKHM1900001'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3VqHuw0wFlIHcIPWkhIbdQ'},
#  'href': 'https://api.spotify.com/v1/tracks/3VqHuw0wFlIHcIPWkhIbdQ',
#  'id': '3VqHuw0wFlIHcIPWkhIbdQ',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Enter Sandman (Remastered)',
#  'popularity': 78,
#  'preview_url': 'https://p.scdn.co/mp3-preview/333dcef73eb5aa95a58ff521fa63d14861dfe2f5?cid=45376cf3a63c421ba5e13941db6a213b',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:3VqHuw0wFlIHcIPWkhIbdQ'}

# %%
print(results['tracks'][0]['id'])
print(results['tracks'][0]['popularity'])
print(results['tracks'][0]['name'])
print(results['tracks'][0]['album']['release_date'])
# Out:
# 3VqHuw0wFlIHcIPWkhIbdQ
# 78
# Enter Sandman (Remastered)
# 1991-08-12

# %%
track_result = []
for i, item in enumerate(results['tracks']):
#     track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    track_result.append((i, artist_name, track['name'], track_id, track_name, item['album']['release_date'], popularity))

# %%
track_result
# Out:
# [(0,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '3VqHuw0wFlIHcIPWkhIbdQ',
#   'Enter Sandman (Remastered)',
#   '1991-08-12',
#   78),
#  (1,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '2CtemffYhT0DJWcT1XW047',
#   'Nothing Else Matters (Remastered)',
#   '1991-08-12',
#   72),
#  (2,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '54bm2e3tk8cliUz3VSdCPZ',
#   'Master of Puppets (Remastered)',
#   '1986-03-03',
#   74),
#  (3,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '51YZAJhOwIC5Gg3jMbAmhZ',
#   'For Whom The Bell Tolls (Remastered)',
#   '1984-07-27',
#   73),
#  (4,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '0LAcM6I7ijW4VVW0aytl1t',
#   'One (Remastered)',
#   '1988-09-07',
#   72),
#  (5,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '7lwvxYumAEo10lzAplRGXM',
#   'The Unforgiven (Remastered)',
#   '1991-08-12',
#   67),
#  (6,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '3ZpWy5rBZv2aLQAldnmTsP',
#   'Whiskey In The Jar',
#   '1998-11-24',
#   66),
#  (7,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '5UaDi8KzCGJqFfVAOBfXhi',
#   'Sad But True (Remastered)',
#   '1991-08-12',
#   68),
#  (8,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '1tTPC0hsnXq1IGpvWY54JC',
#   'Fuel',
#   '1997-11-18',
#   67),
#  (9,
#   'Metallica',
#   'Fade To Black (Remastered)',
#   '0dqGfCMAGyDgpUAgLNOjWd',
#   'Fade To Black (Remastered)',
#   '1984-07-27',
#   66)]

# %%
import pandas as pd
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
track_df
# Out:
#    Item     Artist                  Album Name                      Id  \
# 0     0  Metallica  Fade To Black (Remastered)  3VqHuw0wFlIHcIPWkhIbdQ
# 1     1  Metallica  Fade To Black (Remastered)  2CtemffYhT0DJWcT1XW047
# 2     2  Metallica  Fade To Black (Remastered)  54bm2e3tk8cliUz3VSdCPZ
# 3     3  Metallica  Fade To Black (Remastered)  51YZAJhOwIC5Gg3jMbAmhZ
# 4     4  Metallica  Fade To Black (Remastered)  0LAcM6I7ijW4VVW0aytl1t
# 5     5  Metallica  Fade To Black (Remastered)  7lwvxYumAEo10lzAplRGXM
# 6     6  Metallica  Fade To Black (Remastered)  3ZpWy5rBZv2aLQAldnmTsP
# 7     7  Metallica  Fade To Black (Remastered)  5UaDi8KzCGJqFfVAOBfXhi
# 8     8  Metallica  Fade To Black (Remastered)  1tTPC0hsnXq1IGpvWY54JC
# 9     9  Metallica  Fade To Black (Remastered)  0dqGfCMAGyDgpUAgLNOjWd
#
#                               Song Name Release Date  Popularity
# 0            Enter Sandman (Remastered)   1991-08-12          78
# 1     Nothing Else Matters (Remastered)   1991-08-12          72
# 2        Master of Puppets (Remastered)   1986-03-03          74
# 3  For Whom The Bell Tolls (Remastered)   1984-07-27          73
# 4                      One (Remastered)   1988-09-07          72
# 5           The Unforgiven (Remastered)   1991-08-12          67
# 6                    Whiskey In The Jar   1998-11-24          66
# 7             Sad But True (Remastered)   1991-08-12          68
# 8                                  Fuel   1997-11-18          67
# 9            Fade To Black (Remastered)   1984-07-27          66

# %%
features_df = pd.DataFrame()
for id in track_df['Id'].items():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    features_df = pd.concat([features_df,local_features])

# %%
features_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.566   0.834    6    -8.412     0       0.0298      0.002770
# 0         0.547   0.394    4    -9.793     0       0.0262      0.052200
# 0         0.539   0.828    4    -9.108     0       0.0350      0.000670
# 0         0.512   0.860    0    -6.145     1       0.0703      0.006310
# 0         0.438   0.687    7    -9.150     1       0.0619      0.000668
# 0         0.531   0.583    7    -9.470     1       0.0256      0.018400
# 0         0.511   0.972   10    -3.751     1       0.0413      0.000005
# 0         0.624   0.876    7    -6.005     1       0.0342      0.000926
# 0         0.491   0.951    1    -3.775     1       0.0465      0.000023
# 0         0.256   0.929    7    -6.667     1       0.1130      0.003110
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.008000    0.0625    0.621  123.296  audio_features
# 0          0.000006    0.0795    0.170  142.370  audio_features
# 0          0.421000    0.1540    0.562  105.250  audio_features
# 0          0.005280    0.0652    0.258  117.909  audio_features
# 0          0.080100    0.4200    0.426  103.010  audio_features
# 0          0.006240    0.2550    0.207  139.503  audio_features
# 0          0.001010    0.1900    0.532  132.970  audio_features
# 0          0.001640    0.0561    0.453   89.240  audio_features
# 0          0.003540    0.0424    0.555  106.948  audio_features
# 0          0.201000    0.1100    0.278  113.470  audio_features
#
#                        id                                   uri  \
# 0  3VqHuw0wFlIHcIPWkhIbdQ  spotify:track:3VqHuw0wFlIHcIPWkhIbdQ
# 0  2CtemffYhT0DJWcT1XW047  spotify:track:2CtemffYhT0DJWcT1XW047
# 0  54bm2e3tk8cliUz3VSdCPZ  spotify:track:54bm2e3tk8cliUz3VSdCPZ
# 0  51YZAJhOwIC5Gg3jMbAmhZ  spotify:track:51YZAJhOwIC5Gg3jMbAmhZ
# 0  0LAcM6I7ijW4VVW0aytl1t  spotify:track:0LAcM6I7ijW4VVW0aytl1t
# 0  7lwvxYumAEo10lzAplRGXM  spotify:track:7lwvxYumAEo10lzAplRGXM
# 0  3ZpWy5rBZv2aLQAldnmTsP  spotify:track:3ZpWy5rBZv2aLQAldnmTsP
# 0  5UaDi8KzCGJqFfVAOBfXhi  spotify:track:5UaDi8KzCGJqFfVAOBfXhi
# 0  1tTPC0hsnXq1IGpvWY54JC  spotify:track:1tTPC0hsnXq1IGpvWY54JC
# 0  0dqGfCMAGyDgpUAgLNOjWd  spotify:track:0dqGfCMAGyDgpUAgLNOjWd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3VqHuw0wFlIH...
# 0  https://api.spotify.com/v1/tracks/2CtemffYhT0D...
# 0  https://api.spotify.com/v1/tracks/54bm2e3tk8cl...
# 0  https://api.spotify.com/v1/tracks/51YZAJhOwIC5...
# 0  https://api.spotify.com/v1/tracks/0LAcM6I7ijW4...
# 0  https://api.spotify.com/v1/tracks/7lwvxYumAEo1...
# 0  https://api.spotify.com/v1/tracks/3ZpWy5rBZv2a...
# 0  https://api.spotify.com/v1/tracks/5UaDi8KzCGJq...
# 0  https://api.spotify.com/v1/tracks/1tTPC0hsnXq1...
# 0  https://api.spotify.com/v1/tracks/0dqGfCMAGyDg...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3VqH...       331560
# 0  https://api.spotify.com/v1/audio-analysis/2Cte...       388733
# 0  https://api.spotify.com/v1/audio-analysis/54bm...       515387
# 0  https://api.spotify.com/v1/audio-analysis/51YZ...       309973
# 0  https://api.spotify.com/v1/audio-analysis/0LAc...       446146
# 0  https://api.spotify.com/v1/audio-analysis/7lwv...       387160
# 0  https://api.spotify.com/v1/audio-analysis/3ZpW...       304893
# 0  https://api.spotify.com/v1/audio-analysis/5UaD...       324600
# 0  https://api.spotify.com/v1/audio-analysis/1tTP...       269733
# 0  https://api.spotify.com/v1/audio-analysis/0dqG...       417227
#
#    time_signature
# 0               4
# 0               3
# 0               4
# 0               4
# 0               3
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4

# %%
final_df = track_df.merge(features_df, left_on="Id", right_on="id")

# %%
final_df
# Out:
#    Item     Artist                  Album Name                      Id  \
# 0     0  Metallica  Fade To Black (Remastered)  3VqHuw0wFlIHcIPWkhIbdQ
# 1     1  Metallica  Fade To Black (Remastered)  2CtemffYhT0DJWcT1XW047
# 2     2  Metallica  Fade To Black (Remastered)  54bm2e3tk8cliUz3VSdCPZ
# 3     3  Metallica  Fade To Black (Remastered)  51YZAJhOwIC5Gg3jMbAmhZ
# 4     4  Metallica  Fade To Black (Remastered)  0LAcM6I7ijW4VVW0aytl1t
# 5     5  Metallica  Fade To Black (Remastered)  7lwvxYumAEo10lzAplRGXM
# 6     6  Metallica  Fade To Black (Remastered)  3ZpWy5rBZv2aLQAldnmTsP
# 7     7  Metallica  Fade To Black (Remastered)  5UaDi8KzCGJqFfVAOBfXhi
# 8     8  Metallica  Fade To Black (Remastered)  1tTPC0hsnXq1IGpvWY54JC
# 9     9  Metallica  Fade To Black (Remastered)  0dqGfCMAGyDgpUAgLNOjWd
#
#                               Song Name Release Date  Popularity  \
# 0            Enter Sandman (Remastered)   1991-08-12          78
# 1     Nothing Else Matters (Remastered)   1991-08-12          72
# 2        Master of Puppets (Remastered)   1986-03-03          74
# 3  For Whom The Bell Tolls (Remastered)   1984-07-27          73
# 4                      One (Remastered)   1988-09-07          72
# 5           The Unforgiven (Remastered)   1991-08-12          67
# 6                    Whiskey In The Jar   1998-11-24          66
# 7             Sad But True (Remastered)   1991-08-12          68
# 8                                  Fuel   1997-11-18          67
# 9            Fade To Black (Remastered)   1984-07-27          66
#
#    danceability  energy  key  ...  liveness  valence    tempo            type  \
# 0         0.566   0.834    6  ...    0.0625    0.621  123.296  audio_features
# 1         0.547   0.394    4  ...    0.0795    0.170  142.370  audio_features
# 2         0.539   0.828    4  ...    0.1540    0.562  105.250  audio_features
# 3         0.512   0.860    0  ...    0.0652    0.258  117.909  audio_features
# 4         0.438   0.687    7  ...    0.4200    0.426  103.010  audio_features
# 5         0.531   0.583    7  ...    0.2550    0.207  139.503  audio_features
# 6         0.511   0.972   10  ...    0.1900    0.532  132.970  audio_features
# 7         0.624   0.876    7  ...    0.0561    0.453   89.240  audio_features
# 8         0.491   0.951    1  ...    0.0424    0.555  106.948  audio_features
# 9         0.256   0.929    7  ...    0.1100    0.278  113.470  audio_features
#
#                        id                                   uri  \
# 0  3VqHuw0wFlIHcIPWkhIbdQ  spotify:track:3VqHuw0wFlIHcIPWkhIbdQ
# 1  2CtemffYhT0DJWcT1XW047  spotify:track:2CtemffYhT0DJWcT1XW047
# 2  54bm2e3tk8cliUz3VSdCPZ  spotify:track:54bm2e3tk8cliUz3VSdCPZ
# 3  51YZAJhOwIC5Gg3jMbAmhZ  spotify:track:51YZAJhOwIC5Gg3jMbAmhZ
# 4  0LAcM6I7ijW4VVW0aytl1t  spotify:track:0LAcM6I7ijW4VVW0aytl1t
# 5  7lwvxYumAEo10lzAplRGXM  spotify:track:7lwvxYumAEo10lzAplRGXM
# 6  3ZpWy5rBZv2aLQAldnmTsP  spotify:track:3ZpWy5rBZv2aLQAldnmTsP
# 7  5UaDi8KzCGJqFfVAOBfXhi  spotify:track:5UaDi8KzCGJqFfVAOBfXhi
# 8  1tTPC0hsnXq1IGpvWY54JC  spotify:track:1tTPC0hsnXq1IGpvWY54JC
# 9  0dqGfCMAGyDgpUAgLNOjWd  spotify:track:0dqGfCMAGyDgpUAgLNOjWd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3VqHuw0wFlIH...
# 1  https://api.spotify.com/v1/tracks/2CtemffYhT0D...
# 2  https://api.spotify.com/v1/tracks/54bm2e3tk8cl...
# 3  https://api.spotify.com/v1/tracks/51YZAJhOwIC5...
# 4  https://api.spotify.com/v1/tracks/0LAcM6I7ijW4...
# 5  https://api.spotify.com/v1/tracks/7lwvxYumAEo1...
# 6  https://api.spotify.com/v1/tracks/3ZpWy5rBZv2a...
# 7  https://api.spotify.com/v1/tracks/5UaDi8KzCGJq...
# 8  https://api.spotify.com/v1/tracks/1tTPC0hsnXq1...
# 9  https://api.spotify.com/v1/tracks/0dqGfCMAGyDg...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3VqH...      331560
# 1  https://api.spotify.com/v1/audio-analysis/2Cte...      388733
# 2  https://api.spotify.com/v1/audio-analysis/54bm...      515387
# 3  https://api.spotify.com/v1/audio-analysis/51YZ...      309973
# 4  https://api.spotify.com/v1/audio-analysis/0LAc...      446146
# 5  https://api.spotify.com/v1/audio-analysis/7lwv...      387160
# 6  https://api.spotify.com/v1/audio-analysis/3ZpW...      304893
# 7  https://api.spotify.com/v1/audio-analysis/5UaD...      324600
# 8  https://api.spotify.com/v1/audio-analysis/1tTP...      269733
# 9  https://api.spotify.com/v1/audio-analysis/0dqG...      417227
#
#   time_signature
# 0              4
# 1              3
# 2              4
# 3              4
# 4              3
# 5              4
# 6              4
# 7              4
# 8              4
# 9              4
#
# [10 rows x 25 columns]

# %%
final_df_sorted = final_df.sort_values(by=['Popularity'], ascending=False)

# %%
feature_name = "danceability"

# %%
df_plot = final_df_sorted[['Artist', 'Album Name', 'Song Name', 'Release Date', 'Popularity', f'{feature_name}']]

# %%
df_plot
# Out:
#       Artist                  Album Name  \
# 0  Metallica  Fade To Black (Remastered)
# 2  Metallica  Fade To Black (Remastered)
# 3  Metallica  Fade To Black (Remastered)
# 1  Metallica  Fade To Black (Remastered)
# 4  Metallica  Fade To Black (Remastered)
# 7  Metallica  Fade To Black (Remastered)
# 5  Metallica  Fade To Black (Remastered)
# 8  Metallica  Fade To Black (Remastered)
# 6  Metallica  Fade To Black (Remastered)
# 9  Metallica  Fade To Black (Remastered)
#
#                               Song Name Release Date  Popularity  danceability
# 0            Enter Sandman (Remastered)   1991-08-12          78         0.566
# 2        Master of Puppets (Remastered)   1986-03-03          74         0.539
# 3  For Whom The Bell Tolls (Remastered)   1984-07-27          73         0.512
# 1     Nothing Else Matters (Remastered)   1991-08-12          72         0.547
# 4                      One (Remastered)   1988-09-07          72         0.438
# 7             Sad But True (Remastered)   1991-08-12          68         0.624
# 5           The Unforgiven (Remastered)   1991-08-12          67         0.531
# 8                                  Fuel   1997-11-18          67         0.491
# 6                    Whiskey In The Jar   1998-11-24          66         0.511
# 9            Fade To Black (Remastered)   1984-07-27          66         0.256

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(15, 6), facecolor=(.9, .9, .9))
    
x = df_plot['Song Name']
y = df_plot[feature_name]
s = df_plot['Popularity']*10
    
# color_labels = reco_df['explicit'].unique()
# rgb_values = sns.color_palette("Set1", 8)
# color_map = dict(zip(color_labels, rgb_values))

plt.scatter(x, y, s, alpha=0.7, c=df_plot[feature_name])
plt.xticks(rotation=90)
plt.legend()
# show the graph
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# !pip show altair
# Out:
# Name: altair
# Version: 5.1.1
# Summary: Vega-Altair: A declarative statistical visualization library for Python.
# Home-page:
# Author: Vega-Altair Contributors
# Author-email:
# License:
# Location: c:\users\admin\anaconda3\lib\site-packages
# Requires: jinja2, jsonschema, numpy, packaging, pandas, toolz, typing-extensions
# Required-by: streamlit

# %%
import altair as alt

# %%
alt.Chart(df_plot).mark_circle().encode(
alt.X('Popularity', scale=alt.Scale(zero=False)), y=f'{feature_name}', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity', f'{feature_name}', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)
