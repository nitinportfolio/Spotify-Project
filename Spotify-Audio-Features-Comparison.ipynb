# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
tokens_path = "D:\Various-APITokens-Details\spotify.txt"

# %%
access_token = open(tokens_path,"r").read().split()

# %%
client_id = access_token[2]
client_secret = access_token[-1]

# %%
auth_manager = SpotifyClientCredentials(client_id= client_id, client_secret=client_secret)

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
track_data = sp.search(q='track:'+'shape',type='track', limit=20)

# %%
len(track_data)
# Out:
# 1

# %%
type(track_data)
# Out:
# dict

# %%
track_data.keys()
# Out:
# dict_keys(['tracks'])

# %%
type(track_data["tracks"])
# Out:
# dict

# %%
len(track_data["tracks"])
# Out:
# 7

# %%
track_data["tracks"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(track_data["tracks"]["items"])
# Out:
# 20

# %%
type(track_data["tracks"]["items"])
# Out:
# list

# %%
type(track_data["tracks"]["items"][0])
# Out:
# dict

# %%
track_data["tracks"]["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
track_data["tracks"]["items"][0]["album"].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
#json.loads(track_data["tracks"]["items"][0])

# %%
for i in track_data["tracks"]["items"][0].keys():
    print(i)
    #print(i.keys())
# Out:
# album
# artists
# available_markets
# disc_number
# duration_ms
# explicit
# external_ids
# external_urls
# href
# id
# is_local
# name
# popularity
# preview_url
# track_number
# type
# uri

# %%
for i in track_data["tracks"]["items"][0].keys():
    print(i)
    #print(type(i))
    if type(track_data["tracks"]["items"][0][i]) == dict:
        print(track_data["tracks"]["items"][0][i].keys())
    print("------------")
    
    #print(i.keys())
# Out:
# album
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])
# ------------
# artists
# ------------
# available_markets
# ------------
# disc_number
# ------------
# duration_ms
# ------------
# explicit
# ------------
# external_ids
# dict_keys(['isrc'])
# ------------
# external_urls
# dict_keys(['spotify'])
# ------------
# href
# ------------
# id
# ------------
# is_local
# ------------
# name
# ------------
# popularity
# ------------
# preview_url
# ------------
# track_number
# ------------
# type
# ------------
# uri
# ------------

# %%
for i in track_data["tracks"]["items"][0]["album"].keys():
    print(i)
# Out:
# album_type
# artists
# available_markets
# external_urls
# href
# id
# images
# name
# release_date
# release_date_precision
# total_tracks
# type
# uri

# %%
track_result = []
for i, item in enumerate(track_data["tracks"]["items"]):
    track = item["album"]
    track_id = item["id"]
    track_name = item["name"]
    popularity = item["popularity"]
    track_result.append((i, track['artists'][0]['name'], track['name'], track_id, track_name, track['release_date'], popularity))

# %%
track_result
# Out:
# [(0,
#   'Nirvana',
#   'In Utero (Deluxe Edition)',
#   '11LmqTE2naFULdEP94AUBa',
#   'Heart-Shaped Box',
#   '1993-09-21',
#   81),
#  (1,
#   'Ed Sheeran',
#   '÷ (Deluxe)',
#   '7qiZfU4dY1lWllzX7mPBI3',
#   'Shape of You',
#   '2017-03-03',
#   88),
#  (2,
#   'Backstreet Boys',
#   'Black & Blue',
#   '35o9a4iAfLl5jRmqMX9c1D',
#   'Shape of My Heart',
#   '2000-11-21',
#   75),
#  (3,
#   'Sting',
#   "Ten Summoner's Tales",
#   '6CKoWCWAqEVWVjpeoJXyNH',
#   'Shape Of My Heart',
#   '1993-03-09',
#   75),
#  (4,
#   'Title Fight',
#   'Shed',
#   '6bGDr2wSAAuVvVWhMzax7w',
#   'Crescent-Shaped Depression',
#   '2011-05-03',
#   57),
#  (5,
#   'Taylor Acorn',
#   'Shapeshifting',
#   '2u3HTlrmGMP9jQv17o6UCz',
#   'Shapeshifting',
#   '2022-05-13',
#   59),
#  (6,
#   'Sailors Of The 7 Seas',
#   'Shape Of A Dream',
#   '7M7YsLJWsyu87my5ZnAxau',
#   'Shape Of A Dream',
#   '2021-11-18',
#   57),
#  (7,
#   'Nirvana',
#   'In Utero',
#   '66w5OYw2ja8lnmaA3Ns0PU',
# ...

# %%
import pandas as pd
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
track_df
# Out:
#     Item                 Artist                       Album Name  \
# 0      0                Nirvana        In Utero (Deluxe Edition)
# 1      1             Ed Sheeran                       ÷ (Deluxe)
# 2      2        Backstreet Boys                     Black & Blue
# 3      3                  Sting             Ten Summoner's Tales
# 4      4            Title Fight                             Shed
# 5      5           Taylor Acorn                    Shapeshifting
# 6      6  Sailors Of The 7 Seas                 Shape Of A Dream
# 7      7                Nirvana                         In Utero
# 8      8                 Astron               Peaceful Illusions
# 9      9           Fame on Fire                     Shape of You
# 10    10             Mac Miller                            Faces
# 11    11           Hot Mulligan                   you'll be fine
# 12    12              Passenger               Flight of the Crow
# ...

# %%
type(track_df["Id"])
# Out:
# pandas.core.series.Series

# %%
(track_df["Id"])
# Out:
# 0     11LmqTE2naFULdEP94AUBa
# 1     7qiZfU4dY1lWllzX7mPBI3
# 2     35o9a4iAfLl5jRmqMX9c1D
# 3     6CKoWCWAqEVWVjpeoJXyNH
# 4     6bGDr2wSAAuVvVWhMzax7w
# 5     2u3HTlrmGMP9jQv17o6UCz
# 6     7M7YsLJWsyu87my5ZnAxau
# 7     66w5OYw2ja8lnmaA3Ns0PU
# 8     679ajBE0hA1KXeV4ksYifn
# 9     54SMw8TnDcuieolVRXBmni
# 10    3o6d1KG4HJGWNCP08frPM8
# 11    14YfEnD7lb3LeQW4uwBplm
# 12    6eQYZ57P28uc8caJagxYcZ
# 13    1I7yVk8T0iBMpQXWX71GPs
# 14    1HTR2cbs7Nor722yzYQi63
# 15    67QFTpuf9NUmfi490Uh16b
# 16    1Hgko2YssPJNjOhfJgJ6uo
# 17    1K9yH9EpJsH2kXWX4ozH68
# 18    4UEMZFRrxVUkuMVaHhWoKQ
# 19    4Qs8uJL6dhsJJKl2rX8a9F
# Name: Id, dtype: object

# %%
features_df = pd.DataFrame()
for id in track_df["Id"].iteritems():
    #print(id)
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    #print(audio_features)
    local_features =pd.DataFrame(audio_features, index=[0])
    print(local_features)
    print("------------")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12996\3880865781.py:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for id in track_df["Id"].iteritems():
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.256   0.641    1   -10.283     1       0.0552         0.199
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0            0.0329    0.0853    0.382  203.006  audio_features
#
#                        id                                   uri  \
# 0  11LmqTE2naFULdEP94AUBa  spotify:track:11LmqTE2naFULdEP94AUBa
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/11LmqTE2naFU...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/11Lm...       281160
#
#    time_signature
# 0               4
# ------------
# ...
