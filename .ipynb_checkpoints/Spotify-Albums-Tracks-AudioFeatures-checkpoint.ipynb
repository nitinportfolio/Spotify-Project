# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
tokens_path = "D:\Various-APITokens-Details\spotify.txt"

# %%
access_token = open(tokens_path,"r").read().split()
access_token
# Out:
# ['ClientID',
#  '-',
#  '45376cf3a63c421ba5e13941db6a213b',
#  'ClientSecret',
#  '-',
#  'ebdf5b1bebd8405d8a88cf732484b995']

# %%
client_id = access_token[2]
client_secret = access_token[-1]

# %%
#token

# %%
#secret

# %%
#! pip show spotipy

# %%
auth_manager = SpotifyClientCredentials(client_id= client_id, client_secret=client_secret)

sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
sp.me
# Out:
# <bound method Spotify.me of <spotipy.client.Spotify object at 0x00000247A0417640>>

# %% [markdown]
# # Searching Albums

# %%
albums = sp.search(q="album:"+"shape", type = "album", limit = 20)
# limit - default value is 10

# %%
albums
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=album%3Ashape&type=album&offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#       'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#       'id': '7jy3rLJdDQY21OgRLCZ9sD',
#       'name': 'Foo Fighters',
#       'type': 'artist',
#       'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
# ...

# %%
len(albums['albums'])
# Out:
# 7

# %%
len(albums["albums"]["items"])
# Out:
# 20

# %%
albums["albums"]["items"]
# Out:
# [{'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#     'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#     'id': '7jy3rLJdDQY21OgRLCZ9sD',
#     'name': 'Foo Fighters',
#     'type': 'artist',
#     'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
albums["albums"]["items"][0]
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#    'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#    'id': '7jy3rLJdDQY21OgRLCZ9sD',
#    'name': 'Foo Fighters',
#    'type': 'artist',
#    'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
type(albums["albums"]["items"][0])
# Out:
# dict

# %%
albums_list = albums['albums']['items']
if len(albums_list) > 0:
    for album in albums_list:
        print(album['name'] + " - By - " + album['artists'][0]['name'])
        print("Album ID: " + album['id'] + " / Artist ID - " + album['artists'][0]['id'])
        print("------")
# Out:
# The Colour And The Shape - By - Foo Fighters
# Album ID: 30ly6F6Xl0TKmyBCU50Khv / Artist ID - 7jy3rLJdDQY21OgRLCZ9sD
# ------
# Heart Shaped World - By - Chris Isaak
# Album ID: 5Das42Qx4AoU9iT4M7PW3U / Artist ID - 7290H8m1Dwt8G7jm1y9CQx
# ------
# A Moon Shaped Pool - By - Radiohead
# Album ID: 2ix8vWvvSp2Yo7rKMiWpkg / Artist ID - 4Z8W4fKeB5YxbusRsdQVPb
# ------
# Shaped by Fire - By - As I Lay Dying
# Album ID: 2xgPEwRkAOzsSrNHBx64Ww / Artist ID - 2vd2HnNh4pdYa9gDVHFjEu
# ------
# Shapeshifter - By - Smile Empty Soul
# Album ID: 4t8bZNqNroLlMNj8p908VL / Artist ID - 1KEUVZo7CMTSJoM8doulOT
# ------
# Shapes - By - Self Deception
# Album ID: 2wQM07hTF9pWDI2UTRWjL5 / Artist ID - 0FHW0Lp33r3fvIG0HL4mW0
# ------
# A Shape of Light "A Silent Voice the Movie" Original Soundtrack - By - Kensuke Ushio
# Album ID: 3WlmFFtmePwfhN9pQdVJ5v / Artist ID - 4L0gz16xuM1as1OgYzh1SR
# ------
# Shapes - By - Robohands
# Album ID: 7uTAl4dESGV2JyvUONqURW / Artist ID - 5qRtt9DQNy64ig66kCWFjX
# ------
# ...

# %% [markdown]
# # List of Albums from the Artist

# %%
# To find all the albums by Radio Head
artist_id = "4Z8W4fKeB5YxbusRsdQVPb"

# %%
# sp.+tab - to explore what all you can get

# %%
artist_uri = "spotify:artist:" + artist_id
results = sp.artist_albums(artist_id=artist_uri, album_type="album", limit=20)
albums = results["items"]
print(len(albums))
# Out:
# 14

# %%
albums[0]
# Out:
# dict

# %%
import json
print(json.dumps(albums[0], indent = 4) )
# https://jsonformatter.org/json-viewer
# Out:
# {
#     "album_group": "album",
#     "album_type": "album",
#     "artists": [
#         {
#             "external_urls": {
#                 "spotify": "https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb"
#             },
#             "href": "https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb",
#             "id": "4Z8W4fKeB5YxbusRsdQVPb",
#             "name": "Radiohead",
#             "type": "artist",
#             "uri": "spotify:artist:4Z8W4fKeB5YxbusRsdQVPb"
#         }
#     ],
#     "available_markets": [
#         "AR",
#         "AU",
#         "AT",
#         "BE",
#         "BO",
#         "BR",
#         "BG",
#         "CA",
#         "CL",
#         "CO",
#         "CR",
#         "CY",
#         "CZ",
#         "DK",
#         "DO",
#         "DE",
#         "EC",
#         "EE",
#         "SV",
#         "FI",
#         "FR",
#         "GR",
#         "GT",
#         "HN",
#         "HK",
#         "HU",
#         "IS",
#         "IE",
# ...

# %%
artist_uri = 'spotify:artist:' + artist_id
results = sp.artist_albums(artist_uri, album_type='album', limit=20)
albums = results['items']
# while results['next']:
#     results = sp.next(results)
#     albums.extend(results['items'])

print(len(albums))
albums[0]
# #albums[0]['artists'][0]['name']
# for album in albums:
#     print(album['name'] + " (Singer: " + album['artists'][0]['name'] + " )")
# Out:
# 14
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#    'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#    'id': '4Z8W4fKeB5YxbusRsdQVPb',
#    'name': 'Radiohead',
#    'type': 'artist',
#    'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
# ...
